# %%
import pandas as pd

sensors = pd.read_csv('./air-quality-data-from-extensive-network-of-sensors/sensor_locations.csv')

# %%
def get_query(t, x):
    return """
    IMPORT {} from {}
    """.format(t,x)

# %%
get_query('a', 'b')
# Out:
# '\n    IMPORT a from b\n    '

# %%
sensors.shape[0]
# Out:
# 56

# %%
sensors['dummy'] = [i for i in range(sensors.shape[0])]

# %%
sensors
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>dummy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>50.057748</td>
#       <td>19.961375</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>50.057747</td>
#       <td>19.961374</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>142</td>
#       <td>50.084816</td>
#       <td>19.878066</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>147</td>
#       <td>50.048924</td>
# ...
